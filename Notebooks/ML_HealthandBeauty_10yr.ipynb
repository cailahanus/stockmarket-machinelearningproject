# %%
# Import the dependencies

import os
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Define directory containing the csv files
dir_path = Path("../Resources")

# create an empty list to hold the dataframes 
dfs = []

# loop through each file in the directory
for file in os.listdir(dir_path):
    # check if the file is a csv file
    if file.endswith(".csv"):
        # extract the ticker symbol from the file name (assuming the file name is the ticker symbol)
        ticker = file.replace(".csv", "")
        # Read the file into a DataFrame
        stocks_df = pd.read_csv(dir_path / file)
        # Add a column to the DataFrame to store the ticker symbol
        stocks_df["Ticker"] = ticker
        # add the dataframe to the list
        dfs.append(stocks_df)
        
# concatenate the dataframes in the list
combined_stocks_df = pd.concat(dfs, ignore_index=True)

# Display the combined DataFrame to verify
print(combined_stocks_df.head())

# change the type in 'date' column to datetime
combined_stocks_df["Date"] = pd.to_datetime(combined_stocks_df["Date"])

# Filter the data for the last 20 years from today
twenty_years_ago = pd.Timestamp.today() - pd.DateOffset(years=20)
stocks_data_filtered = combined_stocks_df[combined_stocks_df["Date"] >= twenty_years_ago]

print(stocks_data_filtered.head())
print(stocks_data_filtered.tail())

# List of specific stocks to analyze
stocks_to_analyze = ['ALGN', 'LULU', 'PTON', 'ULTA']

# Initialize dictionaries to hold the MSE and predictions for each stock symbol
mse_dict = {}
predictions_dict = {}

# Iterate through each stock in the list of specific stocks
for stock in stocks_to_analyze:
    # Select the stock's data
    stock_data = stocks_data_filtered[stocks_data_filtered["Ticker"] == stock]
    
    # Display the selected stock data
    print(f"Selected stock data for {stock}:")
    print(stock_data.head())
    
    # Set the date as the index
    stock_data.set_index("Date", inplace=True)
    
    # Define a feature in the data for previous date closing prices
    stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
    
    # Define a feature in the data for the volume
    stock_data["Volume Difference"] = stock_data["Volume"].diff()
    
    # Drop rows with NaN values
    stock_data = stock_data.dropna()
    
    # Define the features (X) and the target (y) variables for training purposes
    X = stock_data[["Previous Day Close", "Volume Difference"]]
    y = stock_data["Close"].values.reshape(-1, 1) 
    
    # Split the data into training and testing sets chronologically
    split = int(0.7 * len(X))
    X_train = X[: split]
    X_test = X[split:]
    y_train = y[: split]
    y_test = y[split:]
    
    # Normalize the data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Define the neural network model
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Train the model with epochs
    model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2)
    
    # Make predictions using the testing data
    predictions = model.predict(X_test_scaled)
    
    # Calculate the mean_squared_error on the testing data
    mse = mean_squared_error(y_test, predictions)
    print(f"MSE for {stock}: {mse}")
    
    # Store the MSE in the dictionary
    mse_dict[stock] = mse
    
    # Make a prediction for the values of the stock over the next year starting from the last date in the dataset
    # Create a dataframe to hold the predictions
    future_dates = pd.date_range(start=stock_data.index[-1], periods=120, freq='M')
    future_dates_df = pd.DataFrame(future_dates, columns=["Date"])
    future_dates_df.set_index("Date", inplace=True)
    
    # Initialize previous_close with the last available close value
    previous_close = stock_data["Close"].iloc[-1]
    volume_difference = 0

    # Predict the future values iteratively
    future_closes = []
    for date in future_dates_df.index:
        # prepare the input data for prediction
        input_data = pd.DataFrame({"Previous Day Close": [previous_close], "Volume Difference": [volume_difference]})
        input_data_scaled = scaler.transform(input_data)
        # Make the prediction
        predicted_close = model.predict(input_data_scaled)[0][0]
        # Append the predicted close to the list
        future_closes.append(predicted_close)
        # Update previous_close for the next iteration
        previous_close = predicted_close
    
    # Add the predictions to the dataframe
    future_dates_df["Close"] = future_closes
    
    # Store the predictions in the dictionary
    predictions_dict[stock] = future_dates_df

# Display the predictions for each stock ticker
for stock, future_dates_df in predictions_dict.items():
    print(f"Predictions for {stock}:")
    print(future_dates_df)

# Define the base path as the parent directory of "Notebooks" and "Resources"
base_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Create a directory named "Predictions" within the base path if it doesn't exist
predictions_folder = os.path.join(base_path, "Health and Beauty Ten Year Predictions")
if not os.path.exists(predictions_folder):
    os.makedirs(predictions_folder)

# Save the Predictions results to individual files in the "Predictions" folder
for stock, future_dates_df in predictions_dict.items():
    prediction_file_path = os.path.join(predictions_folder, f"predictions_{stock}.csv")
    future_dates_df.to_csv(prediction_file_path)

print(f"Prediction results saved to the folder: {predictions_folder}")

# Create a directory named "MSE" within the base path if it doesn't exist
mse_folder = os.path.join(base_path, "Health and Beauty Ten Year MSE Output")
if not os.path.exists(mse_folder):
    os.makedirs(mse_folder)

# Define the path to save the MSE results file
mse_file_path = os.path.join(mse_folder, "mse_results.csv")

# Save the MSE results to a file in the "MSE" folder
mse_df = pd.DataFrame(list(mse_dict.items()), columns=["Stock Ticker", "Mean Squared Error"])
mse_df.to_csv(mse_file_path, index=False)

print(f"MSE results saved to: {mse_file_path}")
# Out:
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_stocks_df = pd.concat(dfs, ignore_index=True)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
#          Date  Open      High       Low     Close  Adj Close     Volume Ticker
# 0  1990-02-16   0.0  0.079861  0.073785  0.077257   0.052392  940636800   CSCO
# 1  1990-02-20   0.0  0.079861  0.074653  0.079861   0.054158  151862400   CSCO
# 2  1990-02-21   0.0  0.078993  0.075521  0.078125   0.052980   70531200   CSCO
# 3  1990-02-22   0.0  0.081597  0.078993  0.078993   0.053569   45216000   CSCO
# 4  1990-02-23   0.0  0.079861  0.078125  0.078559   0.053275   44697600   CSCO
#            Date       Open       High        Low      Close  Adj Close  \
# 3609 2004-06-10  23.670000  23.830000  23.480000  23.820000  16.153521
# 3610 2004-06-14  23.530001  23.660000  23.080000  23.320000  15.814437
# 3611 2004-06-15  23.500000  23.940001  23.430000  23.639999  16.031448
# 3612 2004-06-16  23.760000  23.969999  23.700001  23.879999  16.194208
# 3613 2004-06-17  23.450001  23.590000  23.190001  23.360001  15.841574
#
#         Volume Ticker
# 3609  35949900   CSCO
# 3610  44958400   CSCO
# 3611  60862600   CSCO
# 3612  44052400   CSCO
# 3613  55167200   CSCO
#              Date        Open        High         Low       Close   Adj Close  \
# 524377 2024-04-17  950.000000  952.489990  910.260010  912.260010  912.260010
# 524378 2024-04-18  909.229980  909.330017  884.390015  888.919983  888.919983
# 524379 2024-04-19  894.940002  899.679993  861.950012  870.250000  870.250000
# 524380 2024-04-22  876.400024  878.739990  857.979980  868.070007  868.070007
# 524381 2024-04-23  878.000000  894.299988  868.099976  887.419983  887.419983
#
#          Volume Ticker
# 524377  1668600   LRCX
# 524378  2307400   LRCX
# 524379  1353200   LRCX
# 524380  1856300   LRCX
# 524381   973800   LRCX
# Selected stock data for ALGN:
#              Date       Open       High        Low      Close  Adj Close  \
# 371600 2004-06-10  17.740000  18.559999  17.730000  17.830000  17.830000
# 371601 2004-06-14  17.850000  17.969999  17.400000  17.400000  17.400000
# 371602 2004-06-15  17.389999  18.510000  17.299999  18.299999  18.299999
# 371603 2004-06-16  18.490000  18.600000  18.090000  18.520000  18.520000
# 371604 2004-06-17  18.370001  18.540001  18.100000  18.209999  18.209999
#
#         Volume Ticker
# 371600  446900   ALGN
# 371601  760200   ALGN
# 371602  604000   ALGN
# 371603  556700   ALGN
# 371604  578000   ALGN
# Epoch 1/50
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 825.2682 - val_loss: 19734.3008
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 616.0093 - val_loss: 15247.7842
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 314.6980 - val_loss: 7082.5020
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 147.3850 - val_loss: 1723.0957
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.1423 - val_loss: 294.6825
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.2210 - val_loss: 142.7730
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8469 - val_loss: 133.1490
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1754 - val_loss: 145.0301
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2061 - val_loss: 144.9160
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9443 - val_loss: 155.2134
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7558 - val_loss: 154.7383
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7116 - val_loss: 157.2648
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6719 - val_loss: 157.5266
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9520 - val_loss: 157.2715
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6648 - val_loss: 153.9728
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6251 - val_loss: 159.2489
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5827 - val_loss: 150.6657
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6696 - val_loss: 154.3277
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5904 - val_loss: 151.7211
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7959 - val_loss: 150.6131
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6483 - val_loss: 151.5663
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6849 - val_loss: 149.2264
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5155 - val_loss: 150.3076
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5964 - val_loss: 142.9478
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5362 - val_loss: 141.8703
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5156 - val_loss: 129.6933
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8014 - val_loss: 137.8922
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6778 - val_loss: 133.8877
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5350 - val_loss: 142.8168
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5045 - val_loss: 134.2152
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5818 - val_loss: 139.6839
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6139 - val_loss: 125.5473
# Epoch 33/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5492 - val_loss: 115.8811
# Epoch 34/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5396 - val_loss: 125.9261
# Epoch 35/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5271 - val_loss: 132.0799
# Epoch 36/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5623 - val_loss: 119.4669
# Epoch 37/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5028 - val_loss: 128.8487
# Epoch 38/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4758 - val_loss: 114.9753
# Epoch 39/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4867 - val_loss: 108.7987
# Epoch 40/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4755 - val_loss: 124.0335
# Epoch 41/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5142 - val_loss: 127.4118
# Epoch 42/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5020 - val_loss: 114.4503
# Epoch 43/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4598 - val_loss: 118.9528
# Epoch 44/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5967 - val_loss: 120.1786
# Epoch 45/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4722 - val_loss: 120.1139
# Epoch 46/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4342 - val_loss: 121.9151
# Epoch 47/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5168 - val_loss: 119.1875
# Epoch 48/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5420 - val_loss: 133.3225
# Epoch 49/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4187 - val_loss: 113.1568
# Epoch 50/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4990 - val_loss: 107.6816
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE for ALGN: 1196.6513912232292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=120, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Selected stock data for LULU:
#              Date   Open       High     Low   Close  Adj Close    Volume  \
# 366543 2007-07-27  12.50  14.320000  12.460  14.000     14.000  29257200
# 366544 2007-07-30  14.43  15.925000  14.180  14.990     14.990   5767200
# 366545 2007-07-31  16.00  17.084999  15.105  16.070     16.070   4441600
# 366546 2007-08-01  16.49  16.625000  15.200  15.540     15.540   3063600
# 366547 2007-08-02  16.00  16.915001  15.990  16.525     16.525   1969400
#
#        Ticker
# 366543   LULU
# 366544   LULU
# 366545   LULU
# 366546   LULU
# 366547   LULU
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2413.5439 - val_loss: 8801.1318
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1847.4174 - val_loss: 3377.0186
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 636.0242 - val_loss: 181.7713
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 120.0260 - val_loss: 221.9027
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.9692 - val_loss: 195.6746
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.9433 - val_loss: 127.3967
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.0814 - val_loss: 75.0734
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.0736 - val_loss: 42.5234
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.6901 - val_loss: 25.1311
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9048 - val_loss: 15.9887
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6957 - val_loss: 11.2973
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2577 - val_loss: 9.4854
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6927 - val_loss: 9.0155
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9500 - val_loss: 8.9723
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4332 - val_loss: 9.5358
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4298 - val_loss: 9.2857
# Epoch 17/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2200 - val_loss: 9.0560
# Epoch 18/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2416 - val_loss: 9.0901
# Epoch 19/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7540 - val_loss: 9.6232
# Epoch 20/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9237 - val_loss: 9.0922
# Epoch 21/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5918 - val_loss: 9.6409
# Epoch 22/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7519 - val_loss: 9.6753
# Epoch 23/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7170 - val_loss: 8.8712
# Epoch 24/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5417 - val_loss: 7.9353
# Epoch 25/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7420 - val_loss: 8.6976
# Epoch 26/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8484 - val_loss: 8.2595
# Epoch 27/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5278 - val_loss: 7.4327
# Epoch 28/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6450 - val_loss: 7.1245
# Epoch 29/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5431 - val_loss: 8.2597
# Epoch 30/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4700 - val_loss: 7.3496
# Epoch 31/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5377 - val_loss: 7.4659
# Epoch 32/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4341 - val_loss: 7.0298
# Epoch 33/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6145 - val_loss: 7.9469
# Epoch 34/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6028 - val_loss: 6.9425
# Epoch 35/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7389 - val_loss: 8.2775
# Epoch 36/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4237 - val_loss: 7.0237
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6264 - val_loss: 7.1636
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6838 - val_loss: 7.3599
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3877 - val_loss: 6.5553
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5651 - val_loss: 7.3534
# Epoch 41/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5275 - val_loss: 7.9978
# Epoch 42/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5256 - val_loss: 6.4241
# Epoch 43/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4836 - val_loss: 7.4056
# Epoch 44/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5163 - val_loss: 6.4779
# Epoch 45/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3683 - val_loss: 6.8522
# Epoch 46/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3764 - val_loss: 6.8312
# Epoch 47/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3875 - val_loss: 7.1543
# Epoch 48/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5070 - val_loss: 7.0771
# Epoch 49/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4663 - val_loss: 6.2992
# Epoch 50/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4486 - val_loss: 7.2720
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE for LULU: 70.80950450417191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=120, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Selected stock data for PTON:
#              Date   Open   High    Low  Close  Adj Close    Volume Ticker
# 382118 2019-09-26  27.17  27.98  24.75  25.76      25.76  47067700   PTON
# 382119 2019-09-27  26.17  26.17  23.75  25.24      25.24  15976000   PTON
# 382120 2019-09-30  25.26  25.85  25.00  25.10      25.10   4482900   PTON
# 382121 2019-10-01  25.00  25.17  22.51  22.51      22.51   8816100   PTON
# 382122 2019-10-02  22.25  23.18  21.76  22.60      22.60   9454700   PTON
# Epoch 1/50
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 6763.9795 - val_loss: 123.1619
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6964.8257 - val_loss: 106.4610
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6668.6782 - val_loss: 79.9398
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6179.7461 - val_loss: 47.2316
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5745.3931 - val_loss: 21.5663
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4895.1484 - val_loss: 26.2983
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4076.8845 - val_loss: 84.3657
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2936.7854 - val_loss: 198.6514
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1861.5569 - val_loss: 355.7367
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1177.1870 - val_loss: 440.6361
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 493.7917 - val_loss: 477.1917
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 355.6386 - val_loss: 436.3640
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 168.7015 - val_loss: 381.8950
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 97.1681 - val_loss: 337.3449
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 234.4731 - val_loss: 289.7759
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 85.7304 - val_loss: 277.1372
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 116.8172 - val_loss: 260.1978
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 58.7022 - val_loss: 250.7337
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.1326 - val_loss: 237.1056
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 100.4563 - val_loss: 233.0474
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.8307 - val_loss: 234.7010
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.8818 - val_loss: 229.5908
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.9367 - val_loss: 221.7640
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80.3799 - val_loss: 216.0966
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 56.9453 - val_loss: 210.1226
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.8794 - val_loss: 206.5214
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.4851 - val_loss: 204.2838
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 60.2108 - val_loss: 196.8872
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.9450 - val_loss: 192.9934
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.0603 - val_loss: 188.1896
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.0077 - val_loss: 186.3348
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.6010 - val_loss: 176.2289
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0426 - val_loss: 176.4812
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.1492 - val_loss: 173.7389
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.0128 - val_loss: 171.2079
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.9939 - val_loss: 168.5940
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.8997 - val_loss: 167.6288
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.1656 - val_loss: 163.8298
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.0145 - val_loss: 159.7712
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.8853 - val_loss: 156.6218
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.9130 - val_loss: 152.9920
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.4797 - val_loss: 151.9849
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.3303 - val_loss: 150.6887
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.3981 - val_loss: 144.2443
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5467 - val_loss: 140.3114
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.8575 - val_loss: 140.9978
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.1024 - val_loss: 138.9487
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.1033 - val_loss: 137.3580
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.5532 - val_loss: 134.5219
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.2191 - val_loss: 131.9063
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE for PTON: 219.01293060831242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=120, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Selected stock data for ULTA:
#              Date       Open       High        Low      Close  Adj Close  \
# 107418 2007-10-25  33.000000  35.000000  28.889999  29.820000  29.490023
# 107419 2007-10-26  29.690001  32.980000  29.250000  32.000000  31.645901
# 107420 2007-10-29  34.000000  35.000000  32.650002  34.700001  34.316025
# 107421 2007-10-30  35.220001  35.599998  33.000000  35.430000  35.037945
# 107422 2007-10-31  34.930000  35.630001  32.950001  34.200001  33.821556
#
#          Volume Ticker
# 107418  7486900   ULTA
# 107419  1625600   ULTA
# 107420   667900   ULTA
# 107421   455600   ULTA
# 107422   393200   ULTA
# Epoch 1/50
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 11811.7129 - val_loss: 67433.3047
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10478.1270 - val_loss: 56184.1680
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8715.2275 - val_loss: 30943.2109
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4108.1211 - val_loss: 6505.6528
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 987.4032 - val_loss: 547.4668
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 416.4492 - val_loss: 64.5463
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 268.7253 - val_loss: 40.3236
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 154.5188 - val_loss: 34.6142
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 102.9150 - val_loss: 29.0768
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 87.7875 - val_loss: 28.2417
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 60.0437 - val_loss: 26.1672
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48.1270 - val_loss: 24.9646
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7260 - val_loss: 24.4628
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.6515 - val_loss: 24.8071
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16.5351 - val_loss: 25.6941
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.3223 - val_loss: 24.3734
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.1372 - val_loss: 24.8668
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.5591 - val_loss: 24.6211
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9797 - val_loss: 24.2770
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9235 - val_loss: 24.7139
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7966 - val_loss: 24.5122
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7102 - val_loss: 24.8191
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2303 - val_loss: 25.2694
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6026 - val_loss: 24.6733
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1241 - val_loss: 24.7351
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9592 - val_loss: 25.3155
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0860 - val_loss: 25.1019
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3769 - val_loss: 25.3161
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7719 - val_loss: 25.5164
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4369 - val_loss: 25.0958
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9218 - val_loss: 25.9144
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9870 - val_loss: 25.8309
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5746 - val_loss: 25.5780
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4528 - val_loss: 26.3359
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3334 - val_loss: 25.2379
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4205 - val_loss: 26.8275
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8495 - val_loss: 27.0750
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2346 - val_loss: 25.9656
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5216 - val_loss: 26.6174
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2936 - val_loss: 25.9606
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6043 - val_loss: 26.6712
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9908 - val_loss: 26.5898
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7502 - val_loss: 26.3312
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6171 - val_loss: 25.9374
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9482 - val_loss: 25.3276
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5554 - val_loss: 26.7512
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1912 - val_loss: 26.5469
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3242 - val_loss: 26.5158
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7982 - val_loss: 25.7754
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3781 - val_loss: 26.2384
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# MSE for ULTA: 77.57751238329998
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6900/799825095.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=120, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predictions for ALGN:
#                  Close
# Date
# 2024-04-30  286.220673
# 2024-05-31  263.270599
# 2024-06-30  242.743637
# 2024-07-31  224.395996
# 2024-08-31  208.009674
# ...                ...
# 2033-11-30   64.057846
# 2033-12-31   64.054344
# 2034-01-31   64.051056
# 2034-02-28   64.047951
# 2034-03-31   64.045021
#
# [120 rows x 1 columns]
# Predictions for LULU:
#                  Close
# Date
# 2024-04-30  361.719849
# 2024-05-31  358.777588
# 2024-06-30  355.853027
# 2024-07-31  352.946136
# 2024-08-31  350.056702
# ...                ...
# 2033-11-30  118.859009
# 2033-12-31  117.592407
# 2034-01-31  116.354591
# 2034-02-28  115.144913
# 2034-03-31  113.962715
#
# [120 rows x 1 columns]
# Predictions for PTON:
#                 Close
# Date
# 2024-04-30  21.818760
# 2024-05-31  24.476545
# 2024-06-30  25.703423
# 2024-07-31  26.306398
# 2024-08-31  26.620947
# ...               ...
# 2033-11-30  27.097782
# 2033-12-31  27.097782
# 2034-01-31  27.097782
# 2034-02-28  27.097782
# 2034-03-31  27.097782
#
# [120 rows x 1 columns]
# Predictions for ULTA:
#                  Close
# Date
# 2024-04-30  418.048279
# 2024-05-31  416.832458
# 2024-06-30  415.622559
# 2024-07-31  414.418518
# 2024-08-31  413.220337
# ...                ...
# 2033-11-30  310.730591
# 2033-12-31  310.036133
# 2034-01-31  309.345062
# 2034-02-28  308.657318
# 2034-03-31  307.972900
#
# [120 rows x 1 columns]
# Prediction results saved to the folder: /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/stockmarket-machinelearningproject/Health and Beauty Ten Year Predictions
# MSE results saved to: /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/stockmarket-machinelearningproject/Health and Beauty Ten Year MSE Output/mse_results.csv

# %%
# Function to plot actual vs predicted prices for multiple stocks
def plot_multiple_stocks_actual_vs_predicted(tickers, combined_stocks_df, predictions_dict):
    plt.figure(figsize=(14, 7))
    
    for ticker in tickers:
        # Filter actual prices for the ticker
        actual_prices = combined_stocks_df[combined_stocks_df['Ticker'] == ticker]
        # Get predicted prices for the ticker
        predicted_prices = predictions_dict[ticker]
        
        # Plot actual prices
        plt.plot(actual_prices.index, actual_prices['Close'], label=f"{ticker} Actual")
        # Plot predicted prices
        plt.plot(predicted_prices.index, predicted_prices['Close'], linestyle='dashed', label=f"{ticker} Predicted")
    
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.title("Actual vs Predicted Prices for Health and Beauty Stocks")
    plt.legend()
    plt.show()

# List of tickers to compare
tickers = ['ALGN', 'LULU', 'PTON', 'ULTA']

# Plot the actual vs predicted prices for the specified tickers
plot_multiple_stocks_actual_vs_predicted(tickers, combined_stocks_df, predictions_dict)

# %%
# create a line graph with multiple stocks: BIIB, GILD, INCY, VRTX
# Filter the data for the last 15 years from today
twenty_years_ago = pd.Timestamp.today() - pd.DateOffset(years=20)
stocks_data_filtered = combined_stocks_df[combined_stocks_df["Date"] >= twenty_years_ago] 

# Define the list of tickers to plot
tickers = ['ALGN', 'LULU', 'PTON', 'ULTA']

# Filter the data for the specified tickers
filtered_data = stocks_data_filtered[stocks_data_filtered["Ticker"].isin(tickers)]

# Pivot the data to have the tickers as columns
pivoted_data = filtered_data.pivot(index="Date", columns="Ticker", values="Close")

# Plot the data
pivoted_data.plot(figsize=(14, 7))
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Closing Prices for Health and Beauty Stocks")
plt.show()

# Function to plot the actual and predicted prices for a stock
def plot_actual_vs_predicted(ticker, historical_df, predictions_df):
    plt.figure(figsize=(14, 7))
    plt.plot(historical_df.index, historical_df['Close'], label="Actual Prices")
    plt.plot(predictions_df.index, predictions_df['Close'], label="Predicted Prices", linestyle='dashed')
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.title(f"Actual vs Predicted Prices for {ticker}")
    plt.legend()
    plt.show()

# %%
# create a line graph with bio stocks: ALIGN, LULU, PTON, ULTA for predicted prices.
# Define the list of tickers to plot
tickers = ['ALGN', 'LULU', 'PTON', 'ULTA']

# Plot the actual vs predicted prices for the specified tickers
for ticker in tickers:
    # Get the historical data for the stock
    historical_data = combined_stocks_df[combined_stocks_df["Ticker"] == ticker]
    historical_data.set_index("Date", inplace=True)
    
    # Get the predicted prices for the stock
    predicted_data = predictions_dict[ticker]
    
    # Plot the actual vs predicted prices
    plot_actual_vs_predicted(ticker, historical_data, predicted_data)
    
# Function to plot the actual and predicted prices for a stock
def plot_actual_vs_predicted(ticker, historical_df, predictions_df):
    plt.figure(figsize=(14, 7))
    plt.plot(historical_df.index, historical_df['Close'], label="Actual Prices")
    plt.plot(predictions_df.index, predictions_df['Close'], label="Predicted Prices", linestyle='dashed')
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.title(f"Actual vs Predicted Prices for {ticker}")
    plt.legend()
    plt.show()
