# %%
# Import the dependencies

import os
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Define directory containing the csv files
dir_path = Path("../Resources")

# create an empty list to hold the dataframes 
dfs = []

# loop through each file in the directory
for file in os.listdir(dir_path):
    # check if the file is a csv file
    if file.endswith(".csv"):
        # extract the ticker symbol from the file name (assuming the file name is the ticker symbol)
        ticker = file.replace(".csv", "")
        # Read the file into a DataFrame
        stocks_df = pd.read_csv(dir_path / file)
        # Add a column to the DataFrame to store the ticker symbol
        stocks_df["Ticker"] = ticker
        # add the dataframe to the list
        dfs.append(stocks_df)
        
# concatenate the dataframes in the list
combined_stocks_df = pd.concat(dfs, ignore_index=True)

# Display the combined DataFrame to verify
print(combined_stocks_df.head())

# change the type in 'date' column to datetime
combined_stocks_df["Date"] = pd.to_datetime(combined_stocks_df["Date"])

# Filter the data for the last 15 years from today
ten_years_ago = pd.Timestamp.today() - pd.DateOffset(years=10)
stocks_data_filtered = combined_stocks_df[combined_stocks_df["Date"] >= ten_years_ago]

print(stocks_data_filtered.head())
print(stocks_data_filtered.tail())

# List of specific stocks to analyze
stocks_to_analyze = ['ALGN', 'LULU', 'PTON', 'ULTA']

# Initialize dictionaries to hold the MSE and predictions for each stock symbol
mse_dict = {}
predictions_dict = {}

# Iterate through each stock in the list of specific stocks
for stock in stocks_to_analyze:
    # Select the stock's data
    stock_data = stocks_data_filtered[stocks_data_filtered["Ticker"] == stock]
    
    # Display the selected stock data
    print(f"Selected stock data for {stock}:")
    print(stock_data.head())
    
    # Set the date as the index
    stock_data.set_index("Date", inplace=True)
    
    # Define a feature in the data for previous date closing prices
    stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
    
    # Define a feature in the data for the volume
    stock_data["Volume Difference"] = stock_data["Volume"].diff()
    
    # Drop rows with NaN values
    stock_data = stock_data.dropna()
    
    # Define the features (X) and the target (y) variables for training purposes
    X = stock_data[["Previous Day Close", "Volume Difference"]]
    y = stock_data["Close"].values.reshape(-1, 1) 
    
    # Split the data into training and testing sets chronologically
    split = int(0.7 * len(X))
    X_train = X[: split]
    X_test = X[split:]
    y_train = y[: split]
    y_test = y[split:]
    
    # Normalize the data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Define the neural network model
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Train the model with epochs
    model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2)
    
    # Make predictions using the testing data
    predictions = model.predict(X_test_scaled)
    
    # Calculate the mean_squared_error on the testing data
    mse = mean_squared_error(y_test, predictions)
    print(f"MSE for {stock}: {mse}")
    
    # Store the MSE in the dictionary
    mse_dict[stock] = mse
    
    # Make a prediction for the values of the stock over the next year starting from the last date in the dataset
    # Create a dataframe to hold the predictions
    future_dates = pd.date_range(start=stock_data.index[-1], periods=60, freq='M')
    future_dates_df = pd.DataFrame(future_dates, columns=["Date"])
    future_dates_df.set_index("Date", inplace=True)
    
    # Initialize previous_close with the last available close value
    previous_close = stock_data["Close"].iloc[-1]
    volume_difference = 0

    # Predict the future values iteratively
    future_closes = []
    for date in future_dates_df.index:
        # prepare the input data for prediction
        input_data = pd.DataFrame({"Previous Day Close": [previous_close], "Volume Difference": [volume_difference]})
        input_data_scaled = scaler.transform(input_data)
        # Make the prediction
        predicted_close = model.predict(input_data_scaled)[0][0]
        # Append the predicted close to the list
        future_closes.append(predicted_close)
        # Update previous_close for the next iteration
        previous_close = predicted_close
    
    # Add the predictions to the dataframe
    future_dates_df["Close"] = future_closes
    
    # Store the predictions in the dictionary
    predictions_dict[stock] = future_dates_df

# Display the predictions for each stock ticker
for stock, future_dates_df in predictions_dict.items():
    print(f"Predictions for {stock}:")
    print(future_dates_df)

# Define the base path as the parent directory of "Notebooks" and "Resources"
base_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Create a directory named "Predictions" within the base path if it doesn't exist
predictions_folder = os.path.join(base_path, "Health and Beauty Five Year Predictions")
if not os.path.exists(predictions_folder):
    os.makedirs(predictions_folder)

# Save the Predictions results to individual files in the "Predictions" folder
for stock, future_dates_df in predictions_dict.items():
    prediction_file_path = os.path.join(predictions_folder, f"predictions_{stock}.csv")
    future_dates_df.to_csv(prediction_file_path)

print(f"Prediction results saved to the folder: {predictions_folder}")

# Create a directory named "MSE" within the base path if it doesn't exist
mse_folder = os.path.join(base_path, "Health and Beauty Five Year MSE Output")
if not os.path.exists(mse_folder):
    os.makedirs(mse_folder)

# Define the path to save the MSE results file
mse_file_path = os.path.join(mse_folder, "mse_results.csv")

# Save the MSE results to a file in the "MSE" folder
mse_df = pd.DataFrame(list(mse_dict.items()), columns=["Stock Ticker", "Mean Squared Error"])
mse_df.to_csv(mse_file_path, index=False)

print(f"MSE results saved to: {mse_file_path}")
# Out:
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_stocks_df = pd.concat(dfs, ignore_index=True)
#          Date  Open      High       Low     Close  Adj Close     Volume Ticker
# 0  1990-02-16   0.0  0.079861  0.073785  0.077257   0.052392  940636800   CSCO
# 1  1990-02-20   0.0  0.079861  0.074653  0.079861   0.054158  151862400   CSCO
# 2  1990-02-21   0.0  0.078993  0.075521  0.078125   0.052980   70531200   CSCO
# 3  1990-02-22   0.0  0.081597  0.078993  0.078993   0.053569   45216000   CSCO
# 4  1990-02-23   0.0  0.079861  0.078125  0.078559   0.053275   44697600   CSCO
#            Date       Open       High        Low      Close  Adj Close  \
# 6125 2014-06-10  24.730000  25.100000  24.600000  25.000000  18.296734
# 6126 2014-06-11  24.850000  25.170000  24.790001  25.040001  18.326017
# 6127 2014-06-12  24.950001  25.010000  24.620001  24.660000  18.047903
# 6128 2014-06-13  24.670000  24.780001  24.600000  24.700001  18.077181
# 6129 2014-06-16  24.520000  24.730000  24.450001  24.530001  17.952761
#
#         Volume Ticker
# 6125  36582000   CSCO
# 6126  36170300   CSCO
# 6127  26900400   CSCO
# 6128  20947600   CSCO
# 6129  19251300   CSCO
#              Date        Open        High         Low       Close   Adj Close  \
# 524377 2024-04-17  950.000000  952.489990  910.260010  912.260010  912.260010
# 524378 2024-04-18  909.229980  909.330017  884.390015  888.919983  888.919983
# 524379 2024-04-19  894.940002  899.679993  861.950012  870.250000  870.250000
# 524380 2024-04-22  876.400024  878.739990  857.979980  868.070007  868.070007
# 524381 2024-04-23  878.000000  894.299988  868.099976  887.419983  887.419983
#
#          Volume Ticker
# 524377  1668600   LRCX
# 524378  2307400   LRCX
# 524379  1353200   LRCX
# 524380  1856300   LRCX
# 524381   973800   LRCX
# Selected stock data for ALGN:
#              Date       Open       High        Low      Close  Adj Close  \
# 374116 2014-06-10  53.130001  53.470001  52.070000  52.470001  52.470001
# 374117 2014-06-11  51.849998  52.709999  51.549999  51.599998  51.599998
# 374118 2014-06-12  51.650002  51.860001  50.669998  50.810001  50.810001
# 374119 2014-06-13  51.080002  51.080002  50.310001  50.779999  50.779999
# 374120 2014-06-16  50.689999  51.189999  50.369999  50.950001  50.950001
#
#         Volume Ticker
# 374116  644800   ALGN
# 374117  648100   ALGN
# 374118  826700   ALGN
# 374119  728200   ALGN
# 374120  745100   ALGN
# Epoch 1/50
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35655.7031 - val_loss: 153769.1094
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33324.5469 - val_loss: 148944.7656
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30629.2969 - val_loss: 136633.7656
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28859.0195 - val_loss: 114235.0781
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21938.3086 - val_loss: 81648.8984
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15579.5352 - val_loss: 45229.0703
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8488.8115 - val_loss: 19183.8496
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3940.9841 - val_loss: 5736.0605
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1812.0295 - val_loss: 1398.7000
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 980.2546 - val_loss: 431.0106
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1659.9460 - val_loss: 279.8435
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1173.8253 - val_loss: 220.8850
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 987.3594 - val_loss: 217.2126
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 634.4492 - val_loss: 218.7123
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 562.8433 - val_loss: 216.7091
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 541.6657 - val_loss: 216.1785
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 572.8867 - val_loss: 207.9094
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 840.7466 - val_loss: 212.1860
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 268.1271 - val_loss: 202.9785
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 287.9255 - val_loss: 201.7191
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 292.6350 - val_loss: 200.7557
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 218.8206 - val_loss: 193.4311
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 319.6329 - val_loss: 194.6819
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 319.6339 - val_loss: 193.6614
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 294.0094 - val_loss: 191.6977
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 359.9731 - val_loss: 193.3200
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 191.6848 - val_loss: 185.8514
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.3810 - val_loss: 186.5841
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 242.0509 - val_loss: 181.0587
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.3289 - val_loss: 182.7296
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.1116 - val_loss: 181.5021
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.7310 - val_loss: 178.1389
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142.9827 - val_loss: 176.6061
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95.3408 - val_loss: 177.5114
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 66.6375 - val_loss: 175.9870
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 71.5674 - val_loss: 175.3600
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80.8669 - val_loss: 174.7776
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.8956 - val_loss: 174.8523
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 77.5815 - val_loss: 174.9728
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.0679 - val_loss: 174.3033
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.5255 - val_loss: 174.5380
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.7743 - val_loss: 173.1957
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 66.4515 - val_loss: 172.9015
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.2025 - val_loss: 173.1820
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.3493 - val_loss: 172.4936
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.4486 - val_loss: 172.5508
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.6130 - val_loss: 173.3555
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 67.3476 - val_loss: 171.9256
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.9317 - val_loss: 171.9741
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.7037 - val_loss: 171.0244
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE for ALGN: 131.5234075421324
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=60, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Selected stock data for LULU:
#              Date       Open       High        Low      Close  Adj Close  \
# 368272 2014-06-10  45.230000  46.290001  45.119999  45.480000  45.480000
# 368273 2014-06-11  45.750000  45.790001  44.080002  44.299999  44.299999
# 368274 2014-06-12  37.230000  38.500000  37.000000  37.250000  37.250000
# 368275 2014-06-13  37.150002  37.639999  36.259998  37.610001  37.610001
# 368276 2014-06-16  37.500000  38.299999  37.439999  38.250000  38.250000
#
#           Volume Ticker
# 368272   3538800   LULU
# 368273   5857700   LULU
# 368274  36568200   LULU
# 368275  13793200   LULU
# 368276   5504300   LULU
# Epoch 1/50
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 10901.8184 - val_loss: 90921.9062
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10369.2764 - val_loss: 88963.3672
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9986.0078 - val_loss: 84427.9688
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8671.1221 - val_loss: 76134.7500
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6669.8481 - val_loss: 64128.5156
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4589.7979 - val_loss: 47865.4375
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3214.9026 - val_loss: 30521.6230
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2021.2010 - val_loss: 16596.5469
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1132.1582 - val_loss: 7372.8389
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 625.2546 - val_loss: 2593.9390
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 302.2560 - val_loss: 773.8308
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 244.2308 - val_loss: 229.0108
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 158.9619 - val_loss: 96.6746
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 97.9792 - val_loss: 66.7105
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.8449 - val_loss: 61.0034
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 101.9311 - val_loss: 59.5392
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.9133 - val_loss: 60.2754
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44.4186 - val_loss: 60.6084
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.7350 - val_loss: 60.9305
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.8470 - val_loss: 62.9665
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.2989 - val_loss: 63.1487
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.3440 - val_loss: 65.2151
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.9423 - val_loss: 64.8226
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.5681 - val_loss: 67.1363
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.4669 - val_loss: 67.7983
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.1231 - val_loss: 70.3702
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8548 - val_loss: 72.0330
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.8641 - val_loss: 72.0570
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7337 - val_loss: 71.3507
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3979 - val_loss: 75.6163
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3533 - val_loss: 76.3990
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1831 - val_loss: 77.6455
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9730 - val_loss: 77.5170
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2581 - val_loss: 77.8883
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2732 - val_loss: 80.3997
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6515 - val_loss: 78.8784
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2992 - val_loss: 81.0637
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3844 - val_loss: 81.9076
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7454 - val_loss: 81.4622
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4476 - val_loss: 80.7381
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3416 - val_loss: 83.7979
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6425 - val_loss: 79.6419
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6887 - val_loss: 78.5348
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3205 - val_loss: 80.0270
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2941 - val_loss: 81.3328
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9334 - val_loss: 78.8514
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4836 - val_loss: 78.6405
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6361 - val_loss: 76.7012
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1200 - val_loss: 78.7859
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8350 - val_loss: 76.1413
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# MSE for LULU: 121.50866224413812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=60, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Selected stock data for PTON:
#              Date   Open   High    Low  Close  Adj Close    Volume Ticker
# 382118 2019-09-26  27.17  27.98  24.75  25.76      25.76  47067700   PTON
# 382119 2019-09-27  26.17  26.17  23.75  25.24      25.24  15976000   PTON
# 382120 2019-09-30  25.26  25.85  25.00  25.10      25.10   4482900   PTON
# 382121 2019-10-01  25.00  25.17  22.51  22.51      22.51   8816100   PTON
# 382122 2019-10-02  22.25  23.18  21.76  22.60      22.60   9454700   PTON
# Epoch 1/50
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6819.7510 - val_loss: 112.1425
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7036.3481 - val_loss: 92.2009
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6441.1709 - val_loss: 65.2457
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6547.5366 - val_loss: 35.5633
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5977.6660 - val_loss: 17.1610
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5463.4346 - val_loss: 33.3828
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4716.0825 - val_loss: 105.1683
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3737.0325 - val_loss: 237.4500
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2656.7073 - val_loss: 385.5207
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1677.5111 - val_loss: 499.4432
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 854.8768 - val_loss: 540.9839
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 503.1767 - val_loss: 486.6675
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 232.1877 - val_loss: 407.5789
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 106.4332 - val_loss: 328.2744
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 141.4462 - val_loss: 259.0724
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.5166 - val_loss: 230.9034
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78.2581 - val_loss: 203.2230
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 117.0009 - val_loss: 190.4671
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54.4411 - val_loss: 184.7896
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.0054 - val_loss: 176.1221
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 82.8979 - val_loss: 172.8804
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.3041 - val_loss: 165.1907
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.5343 - val_loss: 163.2775
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.8358 - val_loss: 160.1174
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.8764 - val_loss: 156.9917
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.3132 - val_loss: 150.6496
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.7031 - val_loss: 149.1697
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.1874 - val_loss: 143.4536
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.1459 - val_loss: 142.7928
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.9912 - val_loss: 140.6929
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.0336 - val_loss: 140.0632
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.2534 - val_loss: 135.2944
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.4294 - val_loss: 132.7002
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.3911 - val_loss: 132.1468
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.8952 - val_loss: 130.0902
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.9403 - val_loss: 127.3998
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.0862 - val_loss: 124.8471
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.5632 - val_loss: 120.3579
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.0044 - val_loss: 117.3149
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.9316 - val_loss: 116.2255
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3476 - val_loss: 114.1406
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.5646 - val_loss: 110.8107
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.0784 - val_loss: 110.3159
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.5803 - val_loss: 109.4971
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.6666 - val_loss: 106.8210
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.3043 - val_loss: 106.5069
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.2629 - val_loss: 103.2867
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.1913 - val_loss: 102.0974
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.9509 - val_loss: 100.4201
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.4049 - val_loss: 96.8782
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE for PTON: 166.59444480796958
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=60, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Selected stock data for ULTA:
#              Date       Open       High        Low      Close  Adj Close  \
# 109084 2014-06-10  85.120003  85.639999  84.199997  85.309998  85.309998
# 109085 2014-06-11  96.169998  98.610001  95.500000  97.110001  97.110001
# 109086 2014-06-12  96.540001  96.949997  94.860001  95.000000  95.000000
# 109087 2014-06-13  94.629997  95.550003  94.089996  95.110001  95.110001
# 109088 2014-06-16  94.919998  95.440002  93.750000  94.500000  94.500000
#
#          Volume Ticker
# 109084  3222800   ULTA
# 109085  6442000   ULTA
# 109086  1770700   ULTA
# 109087   770100   ULTA
# 109088   826400   ULTA
# Epoch 1/50
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Previous Day Close"] = stock_data["Close"].shift(1)
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data["Volume Difference"] = stock_data["Volume"].diff()
# /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 54205.1602 - val_loss: 65847.6562
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54491.3242 - val_loss: 64550.8984
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52859.8555 - val_loss: 61402.8008
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 49026.4570 - val_loss: 55135.8203
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42043.1211 - val_loss: 45210.5820
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33507.4258 - val_loss: 32338.7129
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22663.3125 - val_loss: 19268.9824
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13048.3496 - val_loss: 9155.8184
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6339.6440 - val_loss: 3513.7937
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2874.3630 - val_loss: 1448.4602
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2029.7994 - val_loss: 876.1246
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1690.0892 - val_loss: 648.1249
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1255.0413 - val_loss: 506.2834
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1098.4514 - val_loss: 408.2559
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1177.2670 - val_loss: 328.6990
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 795.6214 - val_loss: 265.4491
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 820.6916 - val_loss: 215.3676
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 578.9127 - val_loss: 177.5054
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 394.9365 - val_loss: 145.0193
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 327.8904 - val_loss: 123.6289
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 299.2935 - val_loss: 108.3525
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 539.7523 - val_loss: 94.6528
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 206.3954 - val_loss: 84.7157
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 255.2924 - val_loss: 78.6005
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123.0194 - val_loss: 74.8481
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 208.4936 - val_loss: 72.1718
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 104.5499 - val_loss: 68.6171
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 101.9500 - val_loss: 68.9626
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 146.0781 - val_loss: 68.9084
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 90.7017 - val_loss: 68.5963
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 85.8384 - val_loss: 68.5456
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 83.4741 - val_loss: 69.7912
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 81.2896 - val_loss: 68.8318
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92.7916 - val_loss: 71.1298
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 80.8105 - val_loss: 71.1441
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.4369 - val_loss: 71.2333
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.8673 - val_loss: 71.7417
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.7136 - val_loss: 72.1134
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134.5862 - val_loss: 71.1518
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.5503 - val_loss: 69.7755
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.3943 - val_loss: 70.9941
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.9589 - val_loss: 70.3307
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.6302 - val_loss: 70.3547
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.0850 - val_loss: 69.8640
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.4541 - val_loss: 69.2211
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.6713 - val_loss: 69.5963
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.2253 - val_loss: 68.9901
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.6990 - val_loss: 68.8256
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.4912 - val_loss: 67.6254
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.3426 - val_loss: 67.8684
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE for ULTA: 313.4456965292618
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# /var/folders/f4/7lkrmhr91498yvvn03jsc52c0000gp/T/ipykernel_6988/91361312.py:117: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=stock_data.index[-1], periods=60, freq='M')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predictions for ALGN:
#                  Close
# Date
# 2024-04-30  311.948761
# 2024-05-31  312.017609
# 2024-06-30  312.086548
# 2024-07-31  312.155609
# 2024-08-31  312.224762
# 2024-09-30  312.294037
# 2024-10-31  312.363434
# 2024-11-30  312.432922
# 2024-12-31  312.502533
# 2025-01-31  312.572235
# 2025-02-28  312.641968
# 2025-03-31  312.711853
# 2025-04-30  312.781860
# 2025-05-31  312.851959
# 2025-06-30  312.922180
# 2025-07-31  312.992493
# 2025-08-31  313.062897
# 2025-09-30  313.133423
# 2025-10-31  313.204041
# 2025-11-30  313.274750
# 2025-12-31  313.345581
# 2026-01-31  313.416534
# 2026-02-28  313.487579
# 2026-03-31  313.558716
# 2026-04-30  313.630005
# 2026-05-31  313.701385
# 2026-06-30  313.772888
# 2026-07-31  313.844452
# 2026-08-31  313.916138
# 2026-09-30  313.987915
# 2026-10-31  314.059814
# 2026-11-30  314.131805
# 2026-12-31  314.203918
# 2027-01-31  314.276123
# 2027-02-28  314.348419
# 2027-03-31  314.420868
# 2027-04-30  314.493408
# 2027-05-31  314.566040
# 2027-06-30  314.638824
# 2027-07-31  314.711670
# 2027-08-31  314.784668
# 2027-09-30  314.857758
# 2027-10-31  314.930908
# 2027-11-30  315.004211
# 2027-12-31  315.077606
# 2028-01-31  315.151154
# 2028-02-29  315.224762
# 2028-03-31  315.298492
# 2028-04-30  315.372345
# 2028-05-31  315.446320
# 2028-06-30  315.520416
# 2028-07-31  315.594604
# 2028-08-31  315.668884
# 2028-09-30  315.743286
# 2028-10-31  315.817810
# 2028-11-30  315.892426
# 2028-12-31  315.967102
# 2029-01-31  316.041931
# 2029-02-28  316.116852
# 2029-03-31  316.191925
# Predictions for LULU:
#                  Close
# Date
# 2024-04-30  358.076355
# 2024-05-31  351.756531
# 2024-06-30  345.708344
# 2024-07-31  339.920135
# 2024-08-31  334.380707
# 2024-09-30  329.079376
# 2024-10-31  324.005920
# 2024-11-30  319.150513
# 2024-12-31  314.503784
# 2025-01-31  310.056793
# 2025-02-28  305.800934
# 2025-03-31  301.727997
# 2025-04-30  297.830109
# 2025-05-31  294.099762
# 2025-06-30  290.529724
# 2025-07-31  287.113129
# 2025-08-31  283.843353
# 2025-09-30  280.714142
# 2025-10-31  277.719452
# 2025-11-30  274.853485
# 2025-12-31  272.110687
# 2026-01-31  269.485779
# 2026-02-28  266.973663
# 2026-03-31  264.569550
# 2026-04-30  262.268738
# 2026-05-31  260.066833
# 2026-06-30  257.959595
# 2026-07-31  255.942917
# 2026-08-31  254.012924
# 2026-09-30  252.165878
# 2026-10-31  250.398239
# 2026-11-30  248.706543
# 2026-12-31  247.087585
# 2027-01-31  245.538208
# 2027-02-28  244.055405
# 2027-03-31  242.636368
# 2027-04-30  241.278320
# 2027-05-31  239.978607
# 2027-06-30  238.734787
# 2027-07-31  237.544449
# 2027-08-31  236.405228
# 2027-09-30  235.314972
# 2027-10-31  234.271576
# 2027-11-30  233.273026
# 2027-12-31  232.317337
# 2028-01-31  231.402634
# 2028-02-29  230.527176
# 2028-03-31  229.689240
# 2028-04-30  228.887283
# 2028-05-31  228.119751
# 2028-06-30  227.385101
# 2028-07-31  226.681992
# 2028-08-31  226.009018
# 2028-09-30  225.364944
# 2028-10-31  224.748489
# 2028-11-30  224.158463
# 2028-12-31  223.593781
# 2029-01-31  223.053314
# 2029-02-28  222.535995
# 2029-03-31  222.040909
# Predictions for PTON:
#                 Close
# Date
# 2024-04-30  19.657864
# 2024-05-31  22.952654
# 2024-06-30  24.388472
# 2024-07-31  25.252649
# 2024-08-31  25.790548
# 2024-09-30  26.140738
# 2024-10-31  26.381966
# 2024-11-30  26.551428
# 2024-12-31  26.673943
# 2025-01-31  26.762518
# 2025-02-28  26.826557
# 2025-03-31  26.872850
# 2025-04-30  26.906317
# 2025-05-31  26.930515
# 2025-06-30  26.948013
# 2025-07-31  26.960661
# 2025-08-31  26.969803
# 2025-09-30  26.976414
# 2025-10-31  26.981194
# 2025-11-30  26.984650
# 2025-12-31  26.987148
# 2026-01-31  26.988955
# 2026-02-28  26.990259
# 2026-03-31  26.991207
# 2026-04-30  26.991892
# 2026-05-31  26.992384
# 2026-06-30  26.992739
# 2026-07-31  26.992998
# 2026-08-31  26.993183
# 2026-09-30  26.993319
# 2026-10-31  26.993416
# 2026-11-30  26.993488
# 2026-12-31  26.993538
# 2027-01-31  26.993574
# 2027-02-28  26.993601
# 2027-03-31  26.993622
# 2027-04-30  26.993639
# 2027-05-31  26.993649
# 2027-06-30  26.993656
# 2027-07-31  26.993660
# 2027-08-31  26.993666
# 2027-09-30  26.993666
# 2027-10-31  26.993666
# 2027-11-30  26.993666
# 2027-12-31  26.993666
# 2028-01-31  26.993666
# 2028-02-29  26.993666
# 2028-03-31  26.993666
# 2028-04-30  26.993666
# 2028-05-31  26.993666
# 2028-06-30  26.993666
# 2028-07-31  26.993666
# 2028-08-31  26.993666
# 2028-09-30  26.993666
# 2028-10-31  26.993666
# 2028-11-30  26.993666
# 2028-12-31  26.993666
# 2029-01-31  26.993666
# 2029-02-28  26.993666
# 2029-03-31  26.993666
# Predictions for ULTA:
#                    Close
# Date
# 2024-04-30  4.238279e+02
# 2024-05-31  4.293660e+02
# 2024-06-30  4.361396e+02
# 2024-07-31  4.445135e+02
# 2024-08-31  4.548656e+02
# 2024-09-30  4.677156e+02
# 2024-10-31  4.837908e+02
# 2024-11-30  5.039009e+02
# 2024-12-31  5.290585e+02
# 2025-01-31  5.605306e+02
# 2025-02-28  6.003231e+02
# 2025-03-31  6.510986e+02
# 2025-04-30  7.165522e+02
# 2025-05-31  8.015417e+02
# 2025-06-30  9.121371e+02
# 2025-07-31  1.056053e+03
# 2025-08-31  1.244013e+03
# 2025-09-30  1.490552e+03
# 2025-10-31  1.813992e+03
# 2025-11-30  2.238320e+03
# 2025-12-31  2.795004e+03
# 2026-01-31  3.525697e+03
# 2026-02-28  4.485460e+03
# 2026-03-31  5.746108e+03
# 2026-04-30  7.401967e+03
# 2026-05-31  9.576934e+03
# 2026-06-30  1.243375e+04
# 2026-07-31  1.618617e+04
# 2026-08-31  2.111497e+04
# 2026-09-30  2.758894e+04
# 2026-10-31  3.609249e+04
# 2026-11-30  4.726188e+04
# 2026-12-31  6.193286e+04
# 2027-01-31  8.120370e+04
# 2027-02-28  1.065174e+05
# 2027-03-31  1.397687e+05
# 2027-04-30  1.834469e+05
# 2027-05-31  2.408214e+05
# 2027-06-30  3.161871e+05
# 2027-07-31  4.151855e+05
# 2027-08-31  5.452273e+05
# 2027-09-30  7.160469e+05
# 2027-10-31  9.404311e+05
# 2027-11-30  1.235176e+06
# 2027-12-31  1.622347e+06
# 2028-01-31  2.130923e+06
# 2028-02-29  2.798976e+06
# 2028-03-31  3.676513e+06
# 2028-04-30  4.829224e+06
# 2028-05-31  6.343394e+06
# 2028-06-30  8.332370e+06
# 2028-07-31  1.094504e+07
# 2028-08-31  1.437697e+07
# 2028-09-30  1.888507e+07
# 2028-10-31  2.480679e+07
# 2028-11-30  3.258542e+07
# 2028-12-31  4.280322e+07
# 2029-01-31  5.622506e+07
# 2029-02-28  7.385564e+07
# 2029-03-31  9.701472e+07
# Prediction results saved to the folder: /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/stockmarket-machinelearningproject/Health and Beauty Five Year Predictions
# MSE results saved to: /Users/paulettepetracco/Bootcamp_Code_Challenges/GH_Repositories/Project_4/stockmarket-machinelearningproject/Health and Beauty Five Year MSE Output/mse_results.csv

# %%
plt.figure(figsize=(14, 7))
plt.plot(stock_data.index[split:], y_test, label='Actual Prices')
plt.plot(stock_data.index[split:], predictions, label='Predicted Prices', linestyle='--')
plt.title(f"Actual vs Predicted Stock Prices for {stock}")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
